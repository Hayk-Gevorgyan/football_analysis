# %% [markdown]
# ## Remove backgrounds

# %%
import os

dataset_root = '/content/drive/MyDrive/ball_detection/datasets/ball'
splits = ['train', 'valid', 'test']
image_extensions = ['.jpg', '.png', '.jpeg']

for split in splits:
    images_dir = os.path.join(dataset_root, split, 'images')
    labels_dir = os.path.join(dataset_root, split, 'labels')

    if not os.path.exists(images_dir) or not os.path.exists(labels_dir):
        continue

    for img_fname in os.listdir(images_dir):
        img_name, img_ext = os.path.splitext(img_fname)
        if img_ext.lower() not in image_extensions:
            continue

        label_fname = img_name + '.txt'
        label_path = os.path.join(labels_dir, label_fname)
        img_path = os.path.join(images_dir, img_fname)

        # Remove if label missing
        if not os.path.exists(label_path):
            print(f"Removing image with missing label: {img_path}")
            os.remove(img_path)
            continue

        # Remove if label empty
        with open(label_path, 'r') as f:
            content = f.read().strip()
            if content == '':
                print(f"Removing empty label and image: {label_path}")
                os.remove(label_path)
                os.remove(img_path)
# Out:
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/4b770a_1_2_png.rf.cc814a4adb61ad0478f3c20ef9bb6de1.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_7_3_png_jpg.rf.85b4ba8c87777c190c0128b73374b82e.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/744b27_3_3_png_jpg.rf.c2181df15731068938e642d42ce4c4e7.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_5_5_png_jpg.rf.c4ef871c62dfef249f01746717567fb0.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/08fd33_0_3_png.rf.d34586ebf014e4a9571db487918d45bc.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_5_1_png_jpg.rf.72ab3fdf343794faa806d66961bc7f2b.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/538438_5_10_png.rf.23a4e65366da8923bb93a4c3636803c8.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/08fd33_6_3_png_jpg.rf.045699fdbc54d5e00e97c2066c873054.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/08fd33_6_3_png_jpg.rf.fed0f7f792b3b204eb4be2de5abae577.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_5_5_png.rf.afd22d52d50cf590ac9c713f590ec596.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/538438_3_10_png.rf.f53b8f3d7bbeaddeab0037cd7fb87d52.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/744b27_9_10_png_jpg.rf.60b9fd13c4ff5e53d83405a11b7a6005.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/121364_9_6_png.rf.7825c2453eccca034d6d20ff4edb1052.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/538438_3_10_png_jpg.rf.676ab38f55512980116e2ff33d5bd5d1.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/2e57b9_9_3_png_jpg.rf.cc83ad661b9436f4b94b6d197c984681.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_7_6_png_jpg.rf.efb456c33bebb9e851b2b51520771e17.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/42ba34_7_7_png_jpg.rf.b7a346bd8d9bf1e64d3beb4794cb46bf.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/744b27_3_4_png_jpg.rf.9575295aad59a2c36e3ebc869e9694bc.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/121364_7_7_png.rf.6f936b81b5965b9dc53d639011266cc5.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/744b27_1_5_png.rf.ebf8bc041900c603a4ca82c940a7696f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/42ba34_1_1_png.rf.808b74914055cc1f39a89cf332e23bf9.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/573e61_5_9_png_jpg.rf.a851a70f0466020425c79f98a30b701f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_9_9_png_jpg.rf.7d0d2b02192c9a4e217109de70eb2a79.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/42ba34_1_1_png_jpg.rf.4722df03df648bbe724bc2eb1a9f0749.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/538438_3_8_png.rf.095ef3e3226b4fd5cee3b3f2c43404ed.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/798b45_7_3_png_jpg.rf.8dd1077db54738c055f1f0bd51d3b1b4.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/cd987c_9_8_png_jpg.rf.6dbc8c031f57cb3c59cb8dd9da079e51.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/573e61_7_10_png_jpg.rf.f43a45358ff6b6dd6f69d3e26680dc0f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/08fd33_0_3_png_jpg.rf.4c19ed1862ae6e874d9d23d6ab260328.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/4b770a_1_2_png_jpg.rf.bd5dab5be4e6e01b73deb9c85515c74b.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/54745b_3_9_png.rf.2d4fc10e84929c26ff261afb299adea1.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/train/labels/42ba34
txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/4b770a_1_2_png_jpg.rf.67b2bf93ec9c12e43ffea3dd6afeb29c.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/538438_3_5_png.rf.c14af1af272c719ddb7d09f075d66cf2.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/798b45_7_5_png.rf.de8e5d114d01025a7d83a4cb4c4395bb.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/cd987c_9_8_png.rf.d17119ba54409f02b2268683cf46f3c3.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/573e61_5_9_png_jpg.rf.5c052cefafee6ccf0c695daecc1ee85d.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/08fd33_9_8_png.rf.310d5bd57650711affb96aa2ca83624f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/4b770a_9_9_png_jpg.rf.13dd5a337fa09a65aafdd181ed4bfd5f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/573e61_5_10_png.rf.f1f2bbe6f019a4684903e7e17075a9b4.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/08fd33_9_8_png_jpg.rf.a52e35dab0a342759b0c6bbb61bddac4.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/744b27_3_3_png_jpg.rf.93d48388226ee3cfcce806a38b505e89.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/4b770a_3_2_png_jpg.rf.df8609f93870746eb1e1ec3c796f8fb7.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/08fd33_0_3_png_jpg.rf.a8aab8d16b81645a02a959cb708ad6f3.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/798b45_7_5_png_jpg.rf.31f99d16d1c7298c66b6578c58a69c10.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/08fd33_3_1_png.rf.a8e74a37f852462ae3959fd198e02f3a.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/valid/labels/2e57b9_5_8_png.rf.e7d147572177511e9e4e69d07e7e4cc0.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/798b45_5_5_png_jpg.rf.e8474948577e60511cb57a7a30cb0024.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/a9f16c_2_9_png.rf.d7b37df8bf840e4d22e620cdf9cd89a1.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/121364_9_6_png_jpg.rf.e8864890e3e696fe6da49fe716a48b4f.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/54745b_3_9_png_jpg.rf.77067145e6a3dbf35c3c51926382edf9.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/744b27_9_9_png_jpg.rf.94e9eac25327008c154df308ee2918c0.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/573e61_9_5_png_jpg.rf.5232f0a623923828af18c5f3c323c8db.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/744b27_9_9_png.rf.5c05b565478149b6457b3610cecf2046.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/798b45_5_1_png.rf.be4bd209f2db23c94ce6069c1e8bcb77.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/a9f16c_2_9_png_jpg.rf.403ae9fef0ca5354e51464a90e3fbce5.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/a9f16c_2_6_png.rf.fe074107dd6fff959c8468ae586d93b4.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/744b27_1_5_png_jpg.rf.94e2276218331560bb90b0c22feffcf1.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/121364_7_10_png.rf.65c9f5afa9d826222976efd46824f766.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/42ba34_5_1_png_jpg.rf.a5fb36b5f17e975a2fe1634b7f8d5d01.txt
# Removing empty label and image: /content/drive/MyDrive/ball_detection/datasets/ball/test/labels/4b770a_9_9_png_jpg.rf.5bc82f0674bf8eadc2b3211091a24ad3.txt

# %% [markdown]
# ## Copy dataset

# %%
import shutil
import os

source_folder = '/content/drive/MyDrive/ball_detection/datasets/ball'
destination_folder = '/content/drive/MyDrive/ball_detection/datasets/ball_copy'

# Create the destination folder if it doesn't exist
# if not os.path.exists(destination_folder):
#     os.makedirs(destination_folder)

# Copy the entire folder
shutil.copytree(source_folder, destination_folder)
print(f"Folder copied from '{source_folder}' to '{destination_folder}'")
# Out:
# Folder copied from '/content/drive/MyDrive/ball_detection/datasets/ball' to '/content/drive/MyDrive/ball_detection/datasets/ball_copy'

# %%
# !cp -r /content/drive/MyDrive/ball_detection/datasets/ball /content/drive/MyDrive/ball_detection/datasets/ball_copy

# %%
# !rm -rf /content/drive/MyDrive/ball_detection/datasets/ball_copy

# %% [markdown]
# ## Copy-Paste Augmentation

# %%
import os
import cv2
import random

def copy_paste_augmentation(dataset_root):

    image_dir = os.path.join(dataset_root, "train/images")
    label_dir = os.path.join(dataset_root, "train/labels")

    image_files = sorted([
        f for f in os.listdir(image_dir)
        if f.lower().endswith((".jpg", ".png", ".jpeg"))
    ])

    for img_name in image_files:

        img_path = os.path.join(image_dir, img_name)
        label_path = os.path.join(label_dir, img_name.rsplit(".", 1)[0] + ".txt")

        if not os.path.exists(label_path):
            continue

        img = cv2.imread(img_path)
        if img is None:
            continue

        h, w = img.shape[:2]

        # load + FIX malformed labels
        raw = [ln.strip() for ln in open(label_path) if ln.strip()]
        fixed = []
        for ln in raw:
            p = ln.split()
            for i in range(0, len(p), 5):
                chunk = p[i:i+5]
                if len(chunk) == 5:
                    fixed.append(" ".join(chunk))

        if len(fixed) == 0:
            continue

        # first ball
        cls, xc, yc, bw, bh = map(float, fixed[0].split())

        # pixel coords
        x1 = int((xc - bw / 2) * w)
        y1 = int((yc - bh / 2) * h)
        x2 = int((xc + bw / 2) * w)
        y2 = int((yc + bh / 2) * h)

        crop = img[y1:y2, x1:x2]
        if crop.size == 0:
            continue

        crop_h, crop_w = crop.shape[:2]

        # random anywhere
        paste_x = random.randint(0, w - crop_w)
        paste_y = random.randint(0, h - crop_h)

        img[paste_y:paste_y+crop_h, paste_x:paste_x+crop_w] = crop

        new_xc = (paste_x + crop_w/2) / w
        new_yc = (paste_y + crop_h/2) / h
        new_bw = crop_w / w
        new_bh = crop_h / h

        fixed.append(f"{int(cls)} {new_xc:.6f} {new_yc:.6f} {new_bw:.6f} {new_bh:.6f}")

        cv2.imwrite(img_path, img)
        open(label_path, "w").write("\n".join(fixed) + "\n")

    print("DONE – copy-paste applied to ALL images.")

# %%
copy_paste_augmentation(
    dataset_root="/content/drive/MyDrive/ball_detection/datasets/ball_copy"
)
# Out:
# DONE – copy-paste applied to ALL images.

# %% [markdown]
# ## Modular Copy-Paste Logic

# %%
import os
import cv2
import random


# ---------------------------
# 1. LOAD IMAGE + LABELS
# ---------------------------
def load_image_and_labels(image_dir, label_dir, img_name):
    img_path = os.path.join(image_dir, img_name)
    label_path = os.path.join(label_dir, img_name.rsplit(".", 1)[0] + ".txt")

    if not os.path.exists(label_path):
        return None, None, None, None

    img = cv2.imread(img_path)
    if img is None:
        return None, None, None, None

    with open(label_path, "r") as f:
        labels = [ln.strip() for ln in f.readlines() if ln.strip()]

    return img, labels, img_path, label_path


# ---------------------------
# 2. GET FIRST BALL CROP
# ---------------------------
def extract_crop(img, label_line):
    h, w = img.shape[:2]

    try:
        cls, xc, yc, bw, bh = map(float, label_line.split())
    except:
        return None, None, None, None, None

    # YOLO → pixel
    x1 = int((xc - bw / 2) * w)
    y1 = int((yc - bh / 2) * h)
    x2 = int((xc + bw / 2) * w)
    y2 = int((yc + bh / 2) * h)

    # clamp coordinates
    x1 = max(0, min(x1, w-1))
    y1 = max(0, min(y1, h-1))
    x2 = max(0, min(x2, w))
    y2 = max(0, min(y2, h))

    crop = img[y1:y2, x1:x2]
    if crop.size == 0:
        return None, None, None, None, None

    return crop, (x1, y1, x2, y2), (cls, xc, yc, bw, bh), w, h


# ---------------------------
# 3. CHOOSE PASTE LOCATION: MIDDLE RECTANGLE ONLY
# ---------------------------
def choose_paste_location_middle(w, h, crop_w, crop_h, jitter_frac=0.15):
    """
    Always place the crop somewhere inside the middle (center) 1/3 x 1/3 cell.
    jitter_frac controls how much random offset inside that cell (0.0 = exact center).
    """
    # center cell bounds (pixel)
    cell_w = w // 3
    cell_h = h // 3
    cell_x0 = cell_w     # start x of center cell
    cell_y0 = cell_h     # start y of center cell

    # center of the cell
    center_x = cell_x0 + cell_w // 2
    center_y = cell_y0 + cell_h // 2

    # jitter range (in pixels)
    max_jitter_x = int(jitter_frac * cell_w)
    max_jitter_y = int(jitter_frac * cell_h)

    jitter_x = random.randint(-max_jitter_x, max_jitter_x)
    jitter_y = random.randint(-max_jitter_y, max_jitter_y)

    paste_x = center_x + jitter_x - crop_w // 2
    paste_y = center_y + jitter_y - crop_h // 2

    # clamp so crop is fully inside image
    paste_x = max(0, min(paste_x, w - crop_w))
    paste_y = max(0, min(paste_y, h - crop_h))

    return paste_x, paste_y


# ---------------------------
# 4. PASTE CROP ON IMAGE
# ---------------------------
def paste_crop(img, crop, paste_x, paste_y):
    crop_h, crop_w = crop.shape[:2]
    img[paste_y:paste_y+crop_h, paste_x:paste_x+crop_w] = crop


# ---------------------------
# 5. ADD NEW LABEL
# ---------------------------
def add_new_label(labels, cls, paste_x, paste_y, crop_w, crop_h, w, h):
    new_xc = (paste_x + crop_w / 2) / w
    new_yc = (paste_y + crop_h / 2) / h
    new_bw = crop_w / w
    new_bh = crop_h / h

    labels.append(
        f"{int(cls)} {new_xc:.6f} {new_yc:.6f} {new_bw:.6f} {new_bh:.6f}"
    )
    return labels


# ---------------------------
# MAIN FUNCTION
# ---------------------------
def copy_paste_augmentation_middle_cell(dataset_root, n=3, jitter_frac=0.15):
    """
    dataset_root: path to dataset_root that contains train/images and train/labels
    n: apply augmentation every n-th image
    jitter_frac: how much random jitter inside the center cell (0..1)
    """
    image_dir = os.path.join(dataset_root, "train/images")
    label_dir = os.path.join(dataset_root, "train/labels")

    image_files = sorted([
        f for f in os.listdir(image_dir)
        if f.lower().endswith((".jpg", ".png", ".jpeg"))
    ])

    count = 0
    for idx, img_name in enumerate(image_files):

        if idx % n != 0:
            continue

        img, labels, img_path, label_path = load_image_and_labels(image_dir, label_dir, img_name)
        if img is None or labels is None:
            continue

        crop, bbox, (cls, xc, yc, bw, bh), w, h = extract_crop(img, labels[0])
        if crop is None:
            continue

        crop_h, crop_w = crop.shape[:2]

        paste_x, paste_y = choose_paste_location_middle(w, h, crop_w, crop_h, jitter_frac=jitter_frac)

        paste_crop(img, crop, paste_x, paste_y)
        labels = add_new_label(labels, cls, paste_x, paste_y, crop_w, crop_h, w, h)

        # Save results
        cv2.imwrite(img_path, img)
        with open(label_path, "w") as f:
            f.write("\n".join(labels) + "\n")

        count += 1

    print(f"Copy-paste augmentation (middle cell) completed. Modified {count} images.")

# %%
copy_paste_augmentation_middle_cell(
    dataset_root="/content/drive/MyDrive/ball_detection/datasets/ball_copy",
    n=3,              # every 3rd image
    jitter_frac=0.15  # small random offset inside center rectangle
)
# Out:
# Copy-paste augmentation (middle cell) completed. Modified 203 images.
